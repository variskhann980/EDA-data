# %%
import numpy as np
import pandas as pd

#                           pivot Tables

data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}
df = pd.DataFrame(data)
df
df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    600     57   John  January      Q1
# 1  2023-01-02       B   West    830     37   Mary  January      Q1
# 2  2023-01-03       C  North    208     76    Bob  January      Q1
# 3  2023-01-04       D  South    713     24  Alice  January      Q1
# 4  2023-01-05       A   East    360     88   John  January      Q1
# 5  2023-01-06       B   West    497     25   Mary  January      Q1
# 6  2023-01-07       C  North    692     35    Bob  January      Q1
# 7  2023-01-08       D  South    306     12  Alice  January      Q1
# 8  2023-01-09       A   East    444     47   John  January      Q1
# 9  2023-01-10       B   West    482     44   Mary  January      Q1
# 10 2023-01-11       C  North    651     96    Bob  January      Q1
# 11 2023-01-12       D  South    924     35  Alice  January      Q1
# 12 2023-01-13       A   East    436     50   John  January      Q1
# 13 2023-01-14       B   West    788     74   Mary  January      Q1
# 14 2023-01-15       C  North    385     32    Bob  January      Q1
# 15 2023-01-16       D  South    963     47  Alice  January      Q1
# 16 2023-01-17       A   East    869     66   John  January      Q1
# 17 2023-01-18       B   West    616     23   Mary  January      Q1
# 18 2023-01-19       C  North    485     37    Bob  January      Q1
# 19 2023-01-20       D  South    643     89  Alice  January      Q1

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product',)
# Out:
# Product      A      B      C      D
# Region
# East     541.8    NaN    NaN    NaN
# North      NaN    NaN  484.2    NaN
# South      NaN    NaN    NaN  709.8
# West       NaN  642.6    NaN    NaN
